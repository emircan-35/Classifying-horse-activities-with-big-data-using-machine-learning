# %%
# %run DataPreprocessing.ipynb
# %run FeatureExtraction.ipynb
# %run ActivityPlot.ipynb
# %run MachineLearning.ipynb

# %%
#take them out of command line if and only if the clean csv files are not created locally before 
#createDataFrames()

# %%
#createCleanCSV()

# %%
#get clean csv files
path='C:\\Users\\emirc\\Desktop\\AAR\\codes\\dataHandled\\' #modify the path if needed
dfAll=getCSV(path,'All')
dfBacardi=getCSV(path,'Bacardi')
dfDrieku=getCSV(path,'Drieku')
dfGaloway=getCSV(path,'Galoway')
dfHappy=getCSV(path,'Happy')
dfPatron=getCSV(path,'Patron')
dfZafir=getCSV(path,'Zafir')

# %%
def getAllStatisticsByHorse():
    allStatisticsByHorse={}
    allStatisticsByHorse['Bacardi']=featureExtraction(dfBacardi)
    allStatisticsByHorse['Drieku']=featureExtraction(dfDrieku)
    allStatisticsByHorse['Galoway']=featureExtraction(dfGaloway)
    allStatisticsByHorse['Happy']=featureExtraction(dfHappy)
    allStatisticsByHorse['Patron']=featureExtraction(dfPatron)
    allStatisticsByHorse['Zafir']=featureExtraction(dfZafir)
    allStatisticsByHorse['All']=featureExtraction(dfAll)
    return allStatisticsByHorse

# %%
def storeLocallyStatistics():
    for key in statisticsOfAllHorses:
            statisticsOfAllHorses[key].to_csv('C:\\Users\\emirc\\Desktop\\AAR\\codes\\statistics\\'+key+'.csv',index=False)

# %%
def getAccuracies():
    statistics=getStatistics()
    machine_learning(statistics["All.csv"],"C:\\Users\\emirc\\Desktop\\AAR\\codes\\confusionMatrixes\\All_FINAL")
    """
    i=0
    for statistic in statistics:
            print(statistic+"\n\n")
            machine_learning(statistics[statistic],"C:\\Users\\emirc\\Desktop\\AAR\\codes\\confusionMatrixes\\"+statistic)
            print("##################################\n\n\n")
    """

# %%
#take out of commands if needed to have statistics locally
#statisticsOfAllHorses=getAllStatisticsByHorse() 
#storeLocallyStatistics()

# %%
#take out of commands if needed to have plots of activities
#plot(dfBacardi,"bacardi")
#plot(dfDrieku,"drieku")
#plot(dfGaloway,"galoway")
#plot(dfHappy,"happy")
#plot(dfPatron,"patron")
#plot(dfZafir,"zafir")
#plot(dfAll,"all")

# %%
getAccuracies()
# Out:
# XgBoost - Accuracy <class 'numpy.ndarray'>
# 0.8850724401758099
# [[8.51880878e+01 0.00000000e+00 1.48902821e+00 0.00000000e+00
#   1.33228840e+01]
#  [2.65251989e-01 8.62068966e+01 0.00000000e+00 1.08753316e+01
#   2.65251989e+00]
#  [8.21917808e+00 0.00000000e+00 9.14383562e+01 0.00000000e+00
#   3.42465753e-01]
#  [0.00000000e+00 1.48514851e+00 0.00000000e+00 9.18991899e+01
#   6.61566157e+00]
#  [6.83198381e+00 5.06072874e-02 1.01214575e-01 6.17408907e+00
#   8.68421053e+01]]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1532/802678184.py in <module>
# ----> 1 getAccuracies()
#
# ~\AppData\Local\Temp/ipykernel_1532/2123758316.py in getAccuracies()
#       1 def getAccuracies():
#       2     statistics=getStatistics()
# ----> 3     machine_learning(statistics["Bacardi.csv"],"C:\\Users\\emirc\\Desktop\\AAR\\codes\\confusionMatrixes\\All_FINAL")
#       4     """
#       5     i=0
#
# ~\AppData\Local\Temp/ipykernel_1532/1454633846.py in machine_learning(data, name)
#       1 def machine_learning(data,name):
#       2     print("XgBoost - Accuracy ",end='')
# ----> 3     XgBoost(data,name)
#       4     print()
#       5     """
#
# ~\AppData\Local\Temp/ipykernel_1532/4030999783.py in XgBoost(data, name)
#      10     print(metrics.accuracy_score(y.values.ravel(), y_pred))
#      11     print(conf_mat)
# ---> 12     save_matrix(conf_mat,name)
#
# ~\AppData\Local\Temp/ipykernel_1532/2999794222.py in save_matrix(conf_mat, name)
#      13     plt.xlabel('Predicted Label')
#      14     plt.rcParams.update({'font.size': 25})
# ---> 15     plt.savefig(name+"XgBoost_Conf_Mat.png",dpi=600)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507         """
#     508         FigureCanvasAgg.draw(self)
# --> 509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614         pil_kwargs.setdefault("format", format)
#    1615         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616         image.save(fname, **pil_kwargs)
#    1617
#    1618
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\emirc\\Desktop\\AAR\\codes\\confusionMatrixes\\All_FINALXgBoost_Conf_Mat.png'
