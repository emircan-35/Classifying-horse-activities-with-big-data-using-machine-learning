# %%
# %run DataPreprocessing.ipynb
# %run FeatureExtraction.ipynb
# %run ActivityPlot.ipynb
# %run MachineLearning.ipynb

# %%
#take them out of command line if and only if the clean csv files are not created locally before 
#createDataFrames()

# %%
#createCleanCSV()

# %%
#get clean csv files
path='C:\\Users\\emirc\\Desktop\\AAR\\codes\\dataHandled\\' #modify the path if needed
dfAll=getCSV(path,'All')
dfBacardi=getCSV(path,'Bacardi')
dfDrieku=getCSV(path,'Drieku')
dfGaloway=getCSV(path,'Galoway')
dfHappy=getCSV(path,'Happy')
dfPatron=getCSV(path,'Patron')
dfZafir=getCSV(path,'Zafir')

# %%
def getAllStatisticsByHorse():
    allStatisticsByHorse={}
    allStatisticsByHorse['Bacardi']=featureExtraction(dfBacardi)
    allStatisticsByHorse['Drieku']=featureExtraction(dfDrieku)
    allStatisticsByHorse['Galoway']=featureExtraction(dfGaloway)
    allStatisticsByHorse['Happy']=featureExtraction(dfHappy)
    allStatisticsByHorse['Patron']=featureExtraction(dfPatron)
    allStatisticsByHorse['Zafir']=featureExtraction(dfZafir)
    allStatisticsByHorse['All']=featureExtraction(dfAll)
    return allStatisticsByHorse

# %%
def storeLocallyStatistics():
    for key in statisticsOfAllHorses:
            statisticsOfAllHorses[key].to_csv('C:\\Users\\emirc\\Desktop\\AAR\\codes\\statistics\\'+key+'.csv',index=False)

# %%
def getAccuracies():
    statistics=getStatistics()
    i=0
    for statistic in statistics:
            print(statistic+"\n\n")
            machine_learning(statistics[statistic])
            print("##################################\n\n\n")

# %%
#take out of commands if needed to have statistics locally
#statisticsOfAllHorses=getAllStatisticsByHorse() 
#storeLocallyStatistics()

# %%
#take out of commands if needed to have plots of activities
#plot(dfBacardi)

# %%
getAccuracies()
# Out:
# Bacardi.csv
#
#
# XgBoost - Accuracy 0.8850724401758099
# [[1087    0   19    0  170]
#  [   1  325    0   41   10]
#  [  24    0  267    0    1]
#  [   0   33    0 2042  147]
#  [ 135    1    2  122 1716]]
#
# Extra Trees - Accuracy 0.8783981767865864
# [[1074    0   19    0  183]
#  [   0  323    0   47    7]
#  [  28    0  258    0    6]
#  [   0   45    0 2023  154]
#  [ 127    0    0  131 1718]]
#
# Bagging Trees  - Accuracy 0.8705844050138369
# [[1175    0   26    1   74]
#  [   0  325    2   43    7]
#  [  31    0  255    0    6]
#  [   0   63    0 2015  144]
#  [ 132   22    3  241 1578]]
#
# ada boost - Accuracy 0.7032394595474524
# [[ 397    0  181    0  698]
#  [   0   38    0  326   13]
#  [  22    0  268    0    2]
#  [   0  220    0 1840  162]
#  [ 171    6    2   20 1777]]
#
# random forest - Accuracy 0.8722122741331597
# [[1098    0   24    0  154]
#  [   0  322    0   45   10]
#  [  21    0  265    0    6]
#  [   0   49    0 2017  156]
#  [ 131   17    3  169 1656]]
#
# Light G. Boosting - Accuracy 0.8881653915025232
# [[1106    0   20    0  150]
#  [   0  322    0   43   12]
#  [  24    0  268    0    0]
#  [   0   34    0 2043  145]
#  [ 133    1    2  123 1717]]
#
# G. Boosting - Accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14924/802678184.py in <module>
# ----> 1 getAccuracies()
#
# ~\AppData\Local\Temp/ipykernel_14924/1392590033.py in getAccuracies()
#       5         if statistic!="All.csv":
#       6             print(statistic+"\n\n")
# ----> 7             machine_learning(statistics[statistic])
#       8             print("##################################\n\n\n")
#
# ~\AppData\Local\Temp/ipykernel_14924/2985833726.py in machine_learning(data)
#      25
#      26     print("G. Boosting - Accuracy ",end='')
# ---> 27     G_Boosting(data)
#      28     print()
#      29
#
# ~\AppData\Local\Temp/ipykernel_14924/2287751985.py in G_Boosting(data)
#       3     y = data.iloc[:,52:53]
#       4     model = GradientBoostingClassifier()
# ----> 5     y_pred = cross_val_predict(model, x, y.values.ravel(), cv=10)
#       6     conf_mat = confusion_matrix(y, y_pred)
#       7     print(metrics.accuracy_score(y.values.ravel(), y_pred))
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     961     # independent, and that it is pickle-able.
#     962     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 963     predictions = parallel(
#     964         delayed(_fit_and_predict)(
#     965             clone(estimator), X, y, train, test, verbose, fit_params, method
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     207     def __call__(self, *args, **kwargs):
#     208         with config_context(**self.config):
# --> 209             return self.function(*args, **kwargs)
#     210
#     211
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#    1043         estimator.fit(X_train, **fit_params)
#    1044     else:
# -> 1045         estimator.fit(X_train, y_train, **fit_params)
#    1046     func = getattr(estimator, method)
#    1047     predictions = func(X_test)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     584
#     585         # fit the boosting stages
# --> 586         n_stages = self._fit_stages(
#     587             X,
#     588             y,
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     661
#     662             # fit next stage of trees
# --> 663             raw_predictions = self._fit_stage(
#     664                 i,
#     665                 X,
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244
#     245             X = X_csr if X_csr is not None else X
# --> 246             tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247
#     248             # update tree leaves
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000002D286630820> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     135         FigureCanvasBase(fig)
#     136
# --> 137     fig.canvas.print_figure(bytes_io, **kw)
#     138     data = bytes_io.getvalue()
#     139     if fmt == 'svg':
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1637
#    1638         for a in artists:
# -> 1639             bbox = a.get_tightbbox(renderer)
#    1640             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1641                 bb.append(bbox)
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     304             The enclosing bounding box (in figure pixel coordinates).
#     305         """
# --> 306         bbox = self.get_window_extent(renderer)
#     307         if self.get_clip_on():
#     308             clip_box = self.get_clip_box()
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\collections.py in get_window_extent(self, renderer)
#     303         # TODO: check to ensure that this does not fail for
#     304         # cases other than scatter plot legend
# --> 305         return self.get_datalim(transforms.IdentityTransform())
#     306
#     307     def _prepare_points(self):
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\collections.py in get_datalim(self, transData)
#    2025
#    2026     def get_datalim(self, transData):
# -> 2027         return (self.get_transform() - transData).transform_bbox(self._bbox)
#    2028
#    2029     @staticmethod
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in transform_bbox(self, bbox)
#    1540         Matplotlib), see `TransformedBbox`.
#    1541         """
# -> 1542         return Bbox(self.transform(bbox.get_points()))
#    1543
#    1544     def get_affine(self):
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1468
#    1469         # Transform the values
# -> 1470         res = self.transform_affine(self.transform_non_affine(values))
#    1471
#    1472         # Convert the result back to the shape of the input values.
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2377     def transform_affine(self, points):
#    2378         # docstring inherited
# -> 2379         return self.get_affine().transform(points)
#    2380
#    2381     def transform_non_affine(self, points):
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2404             return self._b.get_affine()
#    2405         else:
# -> 2406             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2407                                    self._a.get_affine().get_matrix()))
#    2408
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2404             return self._b.get_affine()
#    2405         else:
# -> 2406             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2407                                    self._a.get_affine().get_matrix()))
#    2408
#
# c:\users\emirc\appdata\local\programs\python\python39\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1879             # A bit faster than np.identity(3).
#    1880             matrix = IdentityTransform._mtx.copy()
# -> 1881         self._mtx = matrix.copy()
#    1882         self._invalid = 0
#    1883
#
# KeyboardInterrupt:
