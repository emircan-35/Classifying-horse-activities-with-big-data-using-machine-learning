# %%
# %run DataPreprocessing.ipynb
# %run FeatureExtraction.ipynb
# %run ActivityPlot.ipynb
# %run MachineLearning.ipynb

# %%
#take them out of command line if and only if the clean csv files are not created locally before 
#createDataFrames()

# %%
#createCleanCSV()

# %%
#get clean csv files
path='C:\\Users\\emirc\\Desktop\\AAR\\codes\\dataHandled\\' #modify the path if needed
dfAll=getCSV(path,'All')
dfBacardi=getCSV(path,'Bacardi')
dfDrieku=getCSV(path,'Drieku')
dfGaloway=getCSV(path,'Galoway')
dfHappy=getCSV(path,'Happy')
dfPatron=getCSV(path,'Patron')
dfZafir=getCSV(path,'Zafir')

# %%
def getAllStatisticsByHorse():
    allStatisticsByHorse={}
    allStatisticsByHorse['Bacardi']=featureExtraction(dfBacardi)
    allStatisticsByHorse['Drieku']=featureExtraction(dfDrieku)
    allStatisticsByHorse['Galoway']=featureExtraction(dfGaloway)
    allStatisticsByHorse['Happy']=featureExtraction(dfHappy)
    allStatisticsByHorse['Patron']=featureExtraction(dfPatron)
    allStatisticsByHorse['Zafir']=featureExtraction(dfZafir)
    allStatisticsByHorse['All']=featureExtraction(dfAll)
    return allStatisticsByHorse

# %%
def storeLocallyStatistics():
    for key in statisticsOfAllHorses:
            statisticsOfAllHorses[key].to_csv('C:\\Users\\emirc\\Desktop\\AAR\\codes\\statistics\\'+key+'.csv',index=False)

# %%
def getAccuracies():
    statistics=getStatistics()
    for statistic in statistics:
            print(statistic+"\n\n")
            machine_learning(statistics[statistic],"C:\\Users\\emirc\\Desktop\\AAR\\codes\\confusionMatrixes\\"+statistic)
            print("##################################\n\n\n")

# %%
#take out of commands if needed to have statistics locally
#statisticsOfAllHorses=getAllStatisticsByHorse() 
#storeLocallyStatistics()

# %%
#take out of commands if needed to have plots of activities
#plot(dfBacardi,"bacardi")
plot(dfDrieku,"drieku")
#plot(dfGaloway,"galoway")
#plot(dfHappy,"happy")
#plot(dfPatron,"patron")
#plot(dfZafir,"zafir")
#plot(dfAll,"all")

# %%
getAccuracies()
# Out:
# All.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.8985947883592111
# precision | micro -->     0.9256603622214645
# precision | weighted -->  0.9256822096116478
# recall | macro -->        0.8986987686835926
# recall | micro -->        0.9256603622214645
# recall | weighted -->     0.9256603622214645
# F1 | macro -->            0.8982034989967499
# F1 | micro -->            0.9256603622214645
# F1 | weighted -->            0.9252383088115261
# 0.9256603622214645
#
# ##################################
#
#
#
# Bacardi.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.8939350607149853
# precision | micro -->     0.8850724401758099
# precision | weighted -->  0.8857134813218326
# recall | macro -->        0.8831492713451043
# recall | micro -->        0.8850724401758099
# recall | weighted -->     0.8850724401758099
# F1 | macro -->            0.8883533357699743
# F1 | micro -->            0.8850724401758099
# F1 | weighted -->            0.8852512719649727
# 0.8850724401758099
#
# ##################################
#
#
#
# Drieku.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.9671133184899757
# precision | micro -->     0.9716907627045277
# precision | weighted -->  0.9726445777919913
# recall | macro -->        0.9580064821875093
# recall | micro -->        0.9716907627045277
# recall | weighted -->     0.9716907627045277
# F1 | macro -->            0.9621518339818336
# F1 | micro -->            0.9716907627045277
# F1 | weighted -->            0.9717760980233471
# 0.9716907627045277
#
# ##################################
#
#
#
# Galoway.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.9159020852514663
# precision | micro -->     0.9346031519136618
# precision | weighted -->  0.9343530297138042
# recall | macro -->        0.9101065117944804
# recall | micro -->        0.9346031519136618
# recall | weighted -->     0.9346031519136618
# F1 | macro -->            0.9129066273837261
# F1 | micro -->            0.9346031519136618
# F1 | weighted -->            0.9344454841297669
# 0.9346031519136618
#
# ##################################
#
#
#
# Happy.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.953604347335126
# precision | micro -->     0.9652790741086429
# precision | weighted -->  0.9653174497187205
# recall | macro -->        0.9442836094361207
# recall | micro -->        0.9652790741086429
# recall | weighted -->     0.9652790741086429
# F1 | macro -->            0.9487533574368818
# F1 | micro -->            0.9652790741086429
# F1 | weighted -->            0.9652258972634657
# 0.9652790741086429
#
# ##################################
#
#
#
# Patron.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.9519224436902431
# precision | micro -->     0.9611491108071135
# precision | weighted -->  0.9611871666011013
# recall | macro -->        0.9449172599227597
# recall | micro -->        0.9611491108071135
# recall | weighted -->     0.9611491108071135
# F1 | macro -->            0.9482286327250822
# F1 | micro -->            0.9611491108071135
# F1 | weighted -->            0.9610006891367104
# 0.9611491108071135
#
# ##################################
#
#
#
# Zafir.csv
#
#
# XgBoost - Accuracy precision | macro -->     0.9449670662169375
# precision | micro -->     0.9585808188801774
# precision | weighted -->  0.9593424322192161
# recall | macro -->        0.9420374542653225
# recall | micro -->        0.9585808188801774
# recall | weighted -->     0.9585808188801774
# F1 | macro -->            0.9429353597134835
# F1 | micro -->            0.9585808188801774
# F1 | weighted -->            0.9586503450879236
# 0.9585808188801774
#
# ##################################
