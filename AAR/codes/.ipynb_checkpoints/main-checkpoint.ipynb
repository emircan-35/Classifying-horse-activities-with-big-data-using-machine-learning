# %%
# %run DataPreprocessing.ipynb
# %run FeatureExtraction.ipynb
# %run ActivityPlot.ipynb
# %run MachineLearning.ipynb

# %%
#take them out of command line if and only if the clean csv files are not created locally before 
#createDataFrames()

# %%
#createCleanCSV()

# %%
#get clean csv files
path='C:\\Users\\emirc\\Desktop\\AAR\\codes\\dataHandled\\' #modify the path if needed
dfAll=getCSV(path,'All')
dfBacardi=getCSV(path,'Bacardi')
dfDrieku=getCSV(path,'Drieku')
dfGaloway=getCSV(path,'Galoway')
dfHappy=getCSV(path,'Happy')
dfPatron=getCSV(path,'Patron')
dfZafir=getCSV(path,'Zafir')

# %%
def getAllStatisticsByHorse():
    allStatisticsByHorse={}
    allStatisticsByHorse['Bacardi']=featureExtraction(dfBacardi)
    allStatisticsByHorse['Drieku']=featureExtraction(dfDrieku)
    allStatisticsByHorse['Galoway']=featureExtraction(dfGaloway)
    allStatisticsByHorse['Happy']=featureExtraction(dfHappy)
    allStatisticsByHorse['Patron']=featureExtraction(dfPatron)
    allStatisticsByHorse['Zafir']=featureExtraction(dfZafir)
    allStatisticsByHorse['All']=featureExtraction(dfAll)
    return allStatisticsByHorse

# %%
def storeLocallyStatistics():
    for key in statisticsOfAllHorses:
            statisticsOfAllHorses[key].to_csv('C:\\Users\\emirc\\Desktop\\AAR\\codes\\statistics\\'+key+'.csv',index=False)

# %%
def getAccuracies():
    statistics=getStatistics()
    i=0
    for statistic in statistics:
            print(statistic+"\n\n")
            machine_learning(statistics[statistic])
            print("##################################\n\n\n")

# %%
#take out of commands if needed to have statistics locally
#statisticsOfAllHorses=getAllStatisticsByHorse() 
#storeLocallyStatistics()

# %%
#take out of commands if needed to have plots of activities
#plot(dfBacardi)

# %%
getAccuracies()
# Out:
# All.csv
#
#
# XgBoost - Accuracy 0.9256603622214645
# [[15356     0   511     0  2560]
#  [    1  3692     0   807    16]
#  [  331     0  5583     0    66]
#  [    0   965     1 26799   520]
#  [ 1277     3    62   293 40875]]
#
# Extra Trees - Accuracy 0.9202852042760585
# [[14809     0   688     0  2930]
#  [    1  3594     0   911    10]
#  [  399     0  5522     0    59]
#  [    0   856     0 26929   500]
#  [ 1269     2    51   273 40915]]
#
# Bagging Trees  - Accuracy 0.915601997633326
# [[15144     0   691     0  2592]
#  [    1  3632     0   866    17]
#  [  476     1  5448     1    54]
#  [    1  1072     3 26676   533]
#  [ 1543     6    54   505 40402]]
#
# ada boost - Accuracy 0.6859142782647065
# [[11176     0  3290    16  3945]
#  [    0   676     0  3822    18]
#  [  207     0  5138     0   635]
#  [    1  4561     0 23131   592]
#  [ 8579   145   446  5063 28277]]
#
# random forest - Accuracy 0.9245773080085842
# [[15379     0   606     0  2442]
#  [    1  3565     0   935    15]
#  [  420     0  5504     0    56]
#  [    0   869     0 26882   534]
#  [ 1340     2    46   255 40867]]
#
# Light G. Boosting - Accuracy 0.9265027377203714
# [[15503     3   555     0  2366]
#  [    1  3671     0   828    16]
#  [  342     0  5581     1    56]
#  [    1   954     2 26799   529]
#  [ 1287     5    74   309 40835]]
#
# G. Boosting - Accuracy 0.9242363464971218
# [[15614     0   438     0  2375]
#  [    1  3525     0   975    15]
#  [  392     3  5532     0    53]
#  [    0   900     1 26839   545]
#  [ 1436     4    44   373 40653]]
#
# Cat Boosting - Accuracy 0.9237349325096773
# [[15414     0   533     0  2480]
#  [    1  3603     0   898    14]
#  [  359     0  5570     2    49]
#  [    0   910     1 26778   596]
#  [ 1340     3    69   350 40748]]
#
# ##################################
#
#
#
# Bacardi.csv
#
#
# XgBoost - Accuracy 0.8850724401758099
# [[1087    0   19    0  170]
#  [   1  325    0   41   10]
#  [  24    0  267    0    1]
#  [   0   33    0 2042  147]
#  [ 135    1    2  122 1716]]
#
# Extra Trees - Accuracy 0.8801888328178414
# [[1075    0   20    0  181]
#  [   0  319    0   52    6]
#  [  27    0  261    0    4]
#  [   0   43    0 2029  150]
#  [ 122    1    1  129 1723]]
#
# Bagging Trees  - Accuracy 0.8718867003092952
# [[1174    0   24    0   78]
#  [   1  324    0   46    6]
#  [  26    1  259    0    6]
#  [   0   61    0 2017  144]
#  [ 136    5    3  250 1582]]
#
# ada boost - Accuracy 0.7032394595474524
# [[ 397    0  181    0  698]
#  [   0   38    0  326   13]
#  [  22    0  268    0    2]
#  [   0  220    0 1840  162]
#  [ 171    6    2   20 1777]]
#
# random forest - Accuracy 0.8722122741331597
# [[1098    0   24    0  154]
#  [   0  322    0   45   10]
#  [  21    0  265    0    6]
#  [   0   49    0 2017  156]
#  [ 131   17    3  169 1656]]
#
# Light G. Boosting - Accuracy 0.8881653915025232
# [[1106    0   20    0  150]
#  [   0  322    0   43   12]
#  [  24    0  268    0    0]
#  [   0   34    0 2043  145]
#  [ 133    1    2  123 1717]]
#
# G. Boosting - Accuracy 0.887514243854794
# [[1100    0   21    0  155]
#  [   1  328    0   39    9]
#  [  30    0  255    0    7]
#  [   0   49    0 2025  148]
#  [ 135    9    1   87 1744]]
#
# Cat Boosting - Accuracy 0.8814911281132997
# [[1089    0   25    0  162]
#  [   0  324    0   42   11]
#  [  26    0  263    0    3]
#  [   0   49    0 2031  142]
#  [ 129    1    4  134 1708]]
#
# ##################################
#
#
#
# Drieku.csv
#
#
# XgBoost - Accuracy 0.9716907627045277
# [[2833    0   15    0   20]
#  [   3  342    0   23    0]
#  [  24    0  366    0    6]
#  [   5    9    0 2996   11]
#  [ 186    0    2   23 4687]]
#
# Extra Trees - Accuracy 0.9744610856202927
# [[2846    0    7    0   15]
#  [   0  334    0   34    0]
#  [  20    0  369    0    7]
#  [   1    7    0 3001   12]
#  [ 159    0    2   31 4706]]
#
# Bagging Trees  - Accuracy 0.9677084235131157
# [[2826    0    6    0   36]
#  [   7  340    0   21    0]
#  [  32    0  345    0   19]
#  [   6   20    0 2983   12]
#  [ 162    7   15   30 4684]]
#
# ada boost - Accuracy 0.8752488961994632
# [[2323    0    0  545    0]
#  [   4   51    0  309    4]
#  [  63    0  177    4  152]
#  [   7   22    0 2947   45]
#  [ 199    0   23   64 4612]]
#
# random forest - Accuracy 0.9767985455804692
# [[2841    0   12    0   15]
#  [   0  340    0   28    0]
#  [  21    0  372    0    3]
#  [   3   10    0 2997   11]
#  [ 135    8    2   20 4733]]
#
# Light G. Boosting - Accuracy 0.974114795255822
# [[2847    0    6    0   15]
#  [   1  343    0   24    0]
#  [  15    0  376    0    5]
#  [   4    8    0 2998   11]
#  [ 185    0    3   22 4688]]
#
# G. Boosting - Accuracy 0.9767119729893515
# [[2837    0   16    0   15]
#  [   6  330    0   32    0]
#  [  14    0  370    0   12]
#  [   6   10    0 2994   11]
#  [ 129    0    1   17 4751]]
#
# Cat Boosting - Accuracy 0.9729027789801749
# [[2847    0    7    0   14]
#  [   0  341    0   27    0]
#  [  19    0  371    0    6]
#  [   0   12    0 2993   16]
#  [ 184    0    1   27 4686]]
#
# ##################################
#
#
#
# Galoway.csv
#
#
# XgBoost - Accuracy 0.9346031519136618
# [[ 4343     0   167     1   461]
#  [    0  1002     0   181     1]
#  [  136     0  1871     0    41]
#  [    0   133     0  6995   136]
#  [  417     0    37   119 11942]]
#
# Extra Trees - Accuracy 0.9309580816924561
# [[ 4288     0   205     1   478]
#  [    0   974     0   210     0]
#  [  164     0  1843     0    41]
#  [    0   151     0  6990   123]
#  [  401     0    34   124 11956]]
#
# Bagging Trees  - Accuracy 0.9255619483257692
# [[ 4330     0   189     0   453]
#  [    0   989     0   195     0]
#  [  195     0  1814     1    38]
#  [    0   222     2  6900   140]
#  [  460     0    36   152 11867]]
#
# ada boost - Accuracy 0.6841653861272916
# [[  486     0     0     7  4479]
#  [    0  1159     0    24     1]
#  [  204     0     0     0  1844]
#  [    0  1932     0  5134   198]
#  [   42     0     0   107 12366]]
#
# random forest - Accuracy 0.9312082335703821
# [[ 4306     0   210     2   454]
#  [    0   977     0   206     1]
#  [  156     0  1861     0    31]
#  [    1   163     0  6970   130]
#  [  423     0    30   118 11944]]
#
# Light G. Boosting - Accuracy 0.93324518457635
# [[ 4318     0   197     1   456]
#  [    0  1005     0   178     1]
#  [  147     0  1862     0    39]
#  [    0   147     1  6983   133]
#  [  400     0    41   127 11947]]
#
# G. Boosting - Accuracy 0.9299574741807526
# [[ 4270     0   199     3   500]
#  [    0   977     0   206     1]
#  [  168     0  1843     1    36]
#  [    0   177     1  6957   129]
#  [  388     0    37   114 11976]]
#
# Cat Boosting - Accuracy 0.9284565629131973
# [[ 4231     0   234     1   506]
#  [    0   983     0   201     0]
#  [  154     0  1858     1    35]
#  [    2   151     0  6966   145]
#  [  400     0    33   139 11943]]
#
# ##################################
#
#
#
# Happy.csv
#
#
# XgBoost - Accuracy 0.9652790741086429
# [[ 5568     0    16     2   228]
#  [    0   677     0   122     0]
#  [   27     0  1338     1    17]
#  [    0    77     1  7788    25]
#  [  341     0     9    64 10484]]
#
# Extra Trees - Accuracy 0.9662124323315289
# [[ 5582     0    12     1   219]
#  [    0   662     0   137     0]
#  [   36     0  1305     0    42]
#  [    0    87     0  7782    22]
#  [  273     0    13    63 10549]]
#
# Bagging Trees  - Accuracy 0.9592682471532574
# [[ 5568     0    21     2   223]
#  [    0   673     0   126     0]
#  [   25     0  1334     0    24]
#  [    0    99     0  7750    42]
#  [  446     0    14    69 10369]]
#
# ada boost - Accuracy 0.7914504386783647
# [[3347    0  689    0 1778]
#  [   0  432    0  367    0]
#  [  30    0 1340    0   13]
#  [   1  700    0 7152   38]
#  [1833    0   59   78 8928]]
#
# random forest - Accuracy 0.9655030800821355
# [[ 5579     0    13     2   220]
#  [    0   670     0   129     0]
#  [   24     0  1334     0    25]
#  [    0    87     0  7772    32]
#  [  327     0    11    54 10506]]
#
# Light G. Boosting - Accuracy 0.9644577188725033
# [[ 5566     0    16     1   231]
#  [    0   681     0   118     0]
#  [   29     0  1331     0    23]
#  [    0    82     1  7783    25]
#  [  356     0    14    56 10472]]
#
# G. Boosting - Accuracy 0.9634870263207019
# [[ 5569     0    19     3   223]
#  [    0   672     0   127     0]
#  [   27     0  1337     1    18]
#  [    0    94     1  7757    39]
#  [  358     0    10    58 10472]]
#
# Cat Boosting - Accuracy 0.9656524173977973
# [[ 5584     0    18     1   211]
#  [    0   668     0   131     0]
#  [   30     0  1334     3    16]
#  [    0    79     1  7780    31]
#  [  279     0    13   107 10499]]
#
# ##################################
#
#
#
# Patron.csv
# XgBoost - Accuracy 0.9611491108071135
# [[2025    0    3    0  209]
#  [   0  725    0   99    0]
#  [   9    0 1411    1    3]
#  [   0  104    0 3731   21]
#  [  72    0    0   47 6160]]
#
# Extra Trees - Accuracy 0.962311901504788
# [[2050    0    1    0  186]
#  [   0  702    0  122    0]
#  [  10    0 1405    2    7]
#  [   0   93    0 3747   16]
#  [  70    0    1   43 6165]]
#
# Bagging Trees  - Accuracy 0.9582079343365253
# [[2029    0    8    0  200]
#  [   0  728    0   95    1]
#  [   3    0 1416    1    4]
#  [   1  153    0 3682   20]
#  [  83    0    2   40 6154]]
#
# ada boost - Accuracy 0.7625854993160055
# [[ 923    0   67    0 1247]
#  [   0  301    0  522    1]
#  [  31    1  961    0  431]
#  [   0  683    0 3146   27]
#  [ 413    0    2   46 5818]]
#
# random forest - Accuracy 0.9613543091655267
# [[2034    0    6    0  197]
#  [   0  707    0  117    0]
#  [  10    0 1405    0    9]
#  [   0  108    0 3733   15]
#  [  66    0    0   37 6176]]
#
# Light G. Boosting - Accuracy 0.9601231190150479
# [[2011    0    2    0  224]
#  [   0  730    0   94    0]
#  [   9    0 1410    1    4]
#  [   0  104    0 3732   20]
#  [  80    0    2   43 6154]]
#
# G. Boosting - Accuracy 0.9580027359781121
# [[2027    0   10    0  200]
#  [   0  696    0  128    0]
#  [  11    0 1409    0    4]
#  [   0  123    1 3711   21]
#  [  81    1    1   33 6163]]
#
# Cat Boosting - Accuracy 0.9604651162790697
# [[2019    0    1    0  217]
#  [   0  730    0   94    0]
#  [  10    0 1411    1    2]
#  [   0  118    0 3719   19]
#  [  77    0    2   37 6163]]
#
# ##################################
#
#
#
# Zafir.csv
#
#
# XgBoost - Accuracy 0.9585808188801774
# [[1166    0    9    0   87]
#  [   0  894    0   59    1]
#  [  14    0  394    0   18]
#  [   0  144    0 3799  101]
#  [  22    1    8   59 5851]]
#
# Extra Trees - Accuracy 0.9635701275045537
# [[1193    0   12    0   57]
#  [   0  899    0   54    1]
#  [   9    0  384    0   33]
#  [   0  119    0 3831   94]
#  [  21    3   10   47 5860]]
#
# Bagging Trees  - Accuracy 0.9512948443810881
# [[1205    0   15    0   42]
#  [   0  890    0   63    1]
#  [   8    0  398    0   20]
#  [   0  219    0 3721  104]
#  [  32    3   12   96 5798]]
#
# ada boost - Accuracy 0.8160291438979964
# [[ 126    0    0    1 1135]
#  [   0  690    0  263    1]
#  [  11    0   30    0  385]
#  [   0  206    0 3656  182]
#  [  15    2    2  120 5802]]
#
# random forest - Accuracy 0.9621446107547319
# [[1215    0    6    0   41]
#  [   0  891    0   62    1]
#  [   8    0  395    0   23]
#  [   0  151    0 3790  103]
#  [  22    2   12   47 5858]]
#
# Light G. Boosting - Accuracy 0.9553338085055832
# [[1168    0    9    0   85]
#  [   0  899    0   54    1]
#  [   9    0  387    0   30]
#  [   0  185    0 3748  111]
#  [  21    2   10   47 5861]]
#
# G. Boosting - Accuracy 0.9599271402550091
# [[1174    0   13    0   75]
#  [   0  895    0   58    1]
#  [  22    0  395    0    9]
#  [   0  131    0 3818   95]
#  [  23    4    6   69 5839]]
#
# Cat Boosting - Accuracy 0.9599271402550091
# [[1224    0   19    0   19]
#  [   0  891    0   62    1]
#  [   8    0  387    0   31]
#  [   0  122    0 3817  105]
#  [  21    5   20   93 5802]]
#
# ##################################
